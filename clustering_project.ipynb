# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.DataFrame(pd.read_csv("/content/Customers.csv"))
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
row,col = df.shape
print("No of rows = ",row)
print("No of cols = ",col)
# Out:
# No of rows =  2000
# No of cols =  8

# %%
df.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
df.isna().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income ($)',
#        'Spending Score (1-100)', 'Profession', 'Work Experience',
#        'Family Size'],
#       dtype='object')

# %%
df.shape
# Out:
# (1965, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1965 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1965 non-null   int64
#  1   Gender                  1965 non-null   object
#  2   Age                     1965 non-null   int64
#  3   Annual Income ($)       1965 non-null   int64
#  4   Spending Score (1-100)  1965 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         1965 non-null   int64
#  7   Family Size             1965 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 138.2+ KB

# %%
# Checking Null values
df.isnull().sum()
# There are no NULL values in the dataset, hence it is clean.
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
len(set(df['Profession']))
# Out:
# 9

# %%
df = df.drop(['CustomerID'],axis = 1)
df
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  \
# 0       Male   19              15000                      39     Healthcare
# 1       Male   21              35000                      81       Engineer
# 2     Female   20              86000                       6       Engineer
# 3     Female   23              59000                      77         Lawyer
# 4     Female   31              38000                      40  Entertainment
# ...      ...  ...                ...                     ...            ...
# 1995  Female   71             184387                      40         Artist
# 1996  Female   91              73158                      32         Doctor
# 1997    Male   87              90961                      14     Healthcare
# 1998    Male   77             182109                       4      Executive
# 1999    Male   90             110610                      52  Entertainment
#
#       Work Experience  Family Size
# ...

# %%
auto=df[['Gender', 'Age', 'Annual Income ($)',
       'Spending Score (1-100)', 'Work Experience',
       'Family Size']]

# %%
sns.pairplot(auto)

# %%
auto1=df[['Age', 'Annual Income ($)',
       'Spending Score (1-100)', 'Work Experience',
       'Family Size']]
auto1.corr()
# Out:
#                              Age  Annual Income ($)  Spending Score (1-100)  \
# Age                     1.000000           0.021064               -0.037387
# Annual Income ($)       0.021064           1.000000                0.026716
# Spending Score (1-100) -0.037387           0.026716                1.000000
# Work Experience        -0.016771           0.087135               -0.025587
# Family Size             0.034810           0.093757                0.005859
#
#                         Work Experience  Family Size
# Age                           -0.016771     0.034810
# Annual Income ($)              0.087135     0.093757
# Spending Score (1-100)        -0.025587     0.005859
# Work Experience                1.000000     0.012727
# Family Size                    0.012727     1.000000

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto1.corr(),annot=True)
plt.show()

# %%
auto
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 0       Male   19              15000                      39                1
# 1       Male   21              35000                      81                3
# 2     Female   20              86000                       6                1
# 3     Female   23              59000                      77                0
# 4     Female   31              38000                      40                2
# ...      ...  ...                ...                     ...              ...
# 1995  Female   71             184387                      40                8
# 1996  Female   91              73158                      32                7
# 1997    Male   87              90961                      14                9
# 1998    Male   77             182109                       4                7
# 1999    Male   90             110610                      52                5
#
#       Family Size
# ...

# %%
# Dimension reduction

# %%
gender = pd.get_dummies(auto['Gender'], drop_first = True)
gender
# Out:
#        Male
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# ...     ...
# 1995  False
# 1996  False
# 1997   True
# 1998   True
# 1999   True
#
# [1965 rows x 1 columns]

# %%
auto = pd.concat([auto, gender], axis = 1)
auto
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 0       Male   19              15000                      39                1
# 1       Male   21              35000                      81                3
# 2     Female   20              86000                       6                1
# 3     Female   23              59000                      77                0
# 4     Female   31              38000                      40                2
# ...      ...  ...                ...                     ...              ...
# 1995  Female   71             184387                      40                8
# 1996  Female   91              73158                      32                7
# 1997    Male   87              90961                      14                9
# 1998    Male   77             182109                       4                7
# 1999    Male   90             110610                      52                5
#
#       Family Size   Male
# ...

# %%
auto = auto.drop(['Gender'],axis = 1)
auto
# Out:
#       Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 0      19              15000                      39                1
# 1      21              35000                      81                3
# 2      20              86000                       6                1
# 3      23              59000                      77                0
# 4      31              38000                      40                2
# ...   ...                ...                     ...              ...
# 1995   71             184387                      40                8
# 1996   91              73158                      32                7
# 1997   87              90961                      14                9
# 1998   77             182109                       4                7
# 1999   90             110610                      52                5
#
#       Family Size   Male
# 0               4   True
# 1               3   True
# 2               1  False
# ...

# %%
auto.corr()
# Out:
#                              Age  Annual Income ($)  Spending Score (1-100)  \
# Age                     1.000000           0.021064               -0.037387
# Annual Income ($)       0.021064           1.000000                0.026716
# Spending Score (1-100) -0.037387           0.026716                1.000000
# Work Experience        -0.016771           0.087135               -0.025587
# Family Size             0.034810           0.093757                0.005859
# Male                   -0.000504           0.004775                0.003703
#
#                         Work Experience  Family Size      Male
# Age                           -0.016771     0.034810 -0.000504
# Annual Income ($)              0.087135     0.093757  0.004775
# Spending Score (1-100)        -0.025587     0.005859  0.003703
# Work Experience                1.000000     0.012727  0.017418
# Family Size                    0.012727     1.000000 -0.002129
# ...

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
auto['Annual Income ($)'] = auto['Annual Income ($)'].astype('int')

# %%
# Age VS Anual Income

plt.figure(figsize=(10,6))
sns.set_style('darkgrid')

sns.scatterplot(data=auto, x="Work Experience", y= "Annual Income ($)", hue="Male", s=60)
plt.title("Work Experience vs Annual Income ($)\n=================================================================", fontsize=20, color="green")
plt.xlabel("Work Experience", fontsize=15)
plt.ylabel("Annual Income ($)", fontsize=15)
plt.show()

# %%
# Age VS Anual Income

plt.figure(figsize=(10,6))
sns.set_style('darkgrid')

sns.scatterplot(data=auto, x="Age", y= "Annual Income ($)", hue="Male", s=60)
plt.title("Age vs Annual Income ($)\n=================================================================", fontsize=20, color="green")
plt.xlabel("Age", fontsize=15)
plt.ylabel("Annual Income ($)", fontsize=15)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# df_scaled = auto[['Age', 'Annual Income ($)','Spending Score (1-100)', 'Work Experience', 'Family Size']]
df_scaled = auto[['Age', 'Annual Income ($)','Family Size']]

# Class instance
scaler = StandardScaler()

# Fit_transform
df_scaled_fit = scaler.fit_transform(df_scaled)
df_scaled_fit
# Out:
# array([[-1.05234500e+00, -2.08667453e+00,  1.23358006e-01],
#        [-9.81941450e-01, -1.65020484e+00, -3.84814912e-01],
#        [-1.01714323e+00, -5.37207112e-01, -1.40116075e+00],
#        ...,
#        [ 1.34137577e+00, -4.28940804e-01, -8.92987830e-01],
#        [ 9.89358008e-01,  1.56022619e+00, -8.92987830e-01],
#        [ 1.44698110e+00, -1.31151925e-04, -8.92987830e-01]])

# %%
# k-means with some arbitrary k
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(df_scaled_fit)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([3, 3, 3, ..., 0, 0, 0], dtype=int32)

# %%
auto["category"] = kmeans.labels_
df['category'] = kmeans.labels_

# %%
df
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  \
# 0       Male   19              15000                      39     Healthcare
# 1       Male   21              35000                      81       Engineer
# 2     Female   20              86000                       6       Engineer
# 3     Female   23              59000                      77         Lawyer
# 4     Female   31              38000                      40  Entertainment
# ...      ...  ...                ...                     ...            ...
# 1995  Female   71             184387                      40         Artist
# 1996  Female   91              73158                      32         Doctor
# 1997    Male   87              90961                      14     Healthcare
# 1998    Male   77             182109                       4      Executive
# 1999    Male   90             110610                      52  Entertainment
#
#       Work Experience  Family Size  category
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(auto, x='Age', y='Annual Income ($)', z='Family Size',
              color='category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(df, x='Age', y='Annual Income ($)', z='Family Size',
              color='category', symbol='Profession')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculating sum of squared distance

ssd = []

for num_clusters in range(1,11):
    kmeans1 = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans1.fit(df_scaled_fit)

    ssd.append(kmeans1.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# ...

# %%
# Elbow curve

plt.figure(figsize=(12,6))

plt.plot(range(1,11), ssd, linewidth=2, color="red", marker ="8")
plt.title("Elbow Curve\n=================================================================", fontsize=20, color="green")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("SSD")

plt.show()
