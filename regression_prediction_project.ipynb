# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.read_csv("/content/retail_sales_dataset.csv")
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  11/24/2023     CUST001    Male   34           Beauty
# 1                 2   2/27/2023     CUST002  Female   26         Clothing
# 2                 3   1/13/2023     CUST003    Male   50      Electronics
# 3                 4   5/21/2023     CUST004    Male   37         Clothing
# 4                 5    5/6/2023     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996   5/16/2023     CUST996    Male   62         Clothing
# 996             997  11/17/2023     CUST997    Male   52           Beauty
# 997             998  10/29/2023     CUST998  Female   23           Beauty
# 998             999   12/5/2023     CUST999  Female   36      Electronics
# 999            1000   4/12/2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
row,col = df.shape
print("No of rows = ",row)
print("No of cols = ",col)
# Out:
# No of rows =  1000
# No of cols =  9

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
len(set(df['Product Category']))
# Out:
# 3

# %%
df = df.drop(['Transaction ID','Customer ID'],axis = 1)
df
# Out:
#            Date  Gender  Age Product Category  Quantity  Price per Unit  \
# 0    11/24/2023    Male   34           Beauty         3              50
# 1     2/27/2023  Female   26         Clothing         2             500
# 2     1/13/2023    Male   50      Electronics         1              30
# 3     5/21/2023    Male   37         Clothing         1             500
# 4      5/6/2023    Male   30           Beauty         2              50
# ..          ...     ...  ...              ...       ...             ...
# 995   5/16/2023    Male   62         Clothing         1              50
# 996  11/17/2023    Male   52           Beauty         3              30
# 997  10/29/2023  Female   23           Beauty         4              25
# 998   12/5/2023  Female   36      Electronics         3              50
# 999   4/12/2023    Male   47      Electronics         4              30
#
#      Total Amount
# 0             150
# 1            1000
# 2              30
# 3             500
# ...

# %%
auto = df[['Date', 'Gender', 'Age',
       'Product Category', 'Quantity', 'Price per Unit', 'Total Amount']]

# %%
sns.pairplot(auto)

# %%
auto1=df[['Age', 'Quantity','Price per Unit','Total Amount']]
auto1.corr()
# Out:
#                      Age  Quantity  Price per Unit  Total Amount
# Age             1.000000 -0.023737       -0.038423     -0.060568
# Quantity       -0.023737  1.000000        0.017501      0.373707
# Price per Unit -0.038423  0.017501        1.000000      0.851925
# Total Amount   -0.060568  0.373707        0.851925      1.000000

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto1.corr(),annot=True)
plt.show()

# %%
auto
# Out:
#            Date  Gender  Age Product Category  Quantity  Price per Unit  \
# 0    11/24/2023    Male   34           Beauty         3              50
# 1     2/27/2023  Female   26         Clothing         2             500
# 2     1/13/2023    Male   50      Electronics         1              30
# 3     5/21/2023    Male   37         Clothing         1             500
# 4      5/6/2023    Male   30           Beauty         2              50
# ..          ...     ...  ...              ...       ...             ...
# 995   5/16/2023    Male   62         Clothing         1              50
# 996  11/17/2023    Male   52           Beauty         3              30
# 997  10/29/2023  Female   23           Beauty         4              25
# 998   12/5/2023  Female   36      Electronics         3              50
# 999   4/12/2023    Male   47      Electronics         4              30
#
#      Total Amount
# 0             150
# 1            1000
# 2              30
# 3             500
# ...

# %%
#dimension reduction

# %%
Gender = pd.get_dummies(auto['Gender'], drop_first = True)
Gender
# Out:
#       Male
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# ..     ...
# 995   True
# 996   True
# 997  False
# 998  False
# 999   True
#
# [1000 rows x 1 columns]

# %%
auto = pd.concat([auto, Gender], axis = 1)
auto
# Out:
#            Date  Gender  Age Product Category  Quantity  Price per Unit  \
# 0    11/24/2023    Male   34           Beauty         3              50
# 1     2/27/2023  Female   26         Clothing         2             500
# 2     1/13/2023    Male   50      Electronics         1              30
# 3     5/21/2023    Male   37         Clothing         1             500
# 4      5/6/2023    Male   30           Beauty         2              50
# ..          ...     ...  ...              ...       ...             ...
# 995   5/16/2023    Male   62         Clothing         1              50
# 996  11/17/2023    Male   52           Beauty         3              30
# 997  10/29/2023  Female   23           Beauty         4              25
# 998   12/5/2023  Female   36      Electronics         3              50
# 999   4/12/2023    Male   47      Electronics         4              30
#
#      Total Amount   Male
# 0             150   True
# 1            1000  False
# ...

# %%
len(set(auto['Product Category']))
# Out:
# 3

# %%
auto = auto.drop(['Gender','Product Category'],axis = 1)
auto
# Out:
#            Date  Age  Quantity  Price per Unit  Total Amount   Male
# 0    11/24/2023   34         3              50           150   True
# 1     2/27/2023   26         2             500          1000  False
# 2     1/13/2023   50         1              30            30   True
# 3     5/21/2023   37         1             500           500   True
# 4      5/6/2023   30         2              50           100   True
# ..          ...  ...       ...             ...           ...    ...
# 995   5/16/2023   62         1              50            50   True
# 996  11/17/2023   52         3              30            90   True
# 997  10/29/2023   23         4              25           100  False
# 998   12/5/2023   36         3              50           150  False
# 999   4/12/2023   47         4              30           120   True
#
# [1000 rows x 6 columns]

# %%
auto['Date'] = pd.to_datetime(auto['Date'])
auto['DayOfWeek'] = auto['Date'].dt.dayofweek
auto = auto.drop('Date', axis=1)
auto.corr()
# Out:
#                      Age  Quantity  Price per Unit  Total Amount      Male  \
# Age             1.000000 -0.023737       -0.038423     -0.060568  0.002621
# Quantity       -0.023737  1.000000        0.017501      0.373707 -0.028023
# Price per Unit -0.038423  0.017501        1.000000      0.851925 -0.000961
# Total Amount   -0.060568  0.373707        0.851925      1.000000 -0.001001
# Male            0.002621 -0.028023       -0.000961     -0.001001  1.000000
# DayOfWeek       0.024743 -0.040846        0.041272      0.009262 -0.008338
#
#                 DayOfWeek
# Age              0.024743
# Quantity        -0.040846
# Price per Unit   0.041272
# Total Amount     0.009262
# Male            -0.008338
# DayOfWeek        1.000000

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
sns.pairplot(auto)

# %%
auto = auto.drop(['Male'],axis = 1)
auto
# Out:
#      Age  Quantity  Price per Unit  Total Amount  DayOfWeek
# 0     34         3              50           150          4
# 1     26         2             500          1000          0
# 2     50         1              30            30          4
# 3     37         1             500           500          6
# 4     30         2              50           100          5
# ..   ...       ...             ...           ...        ...
# 995   62         1              50            50          1
# 996   52         3              30            90          4
# 997   23         4              25           100          6
# 998   36         3              50           150          1
# 999   47         4              30           120          2
#
# [1000 rows x 5 columns]

# %%
auto['Total Amount'] = auto['Total Amount'].astype('int')

# %%
from sklearn.model_selection import train_test_split
# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.85, test_size = 0.15, random_state = 1)

# %%
df_train
# Out:
#      Age  Quantity  Price per Unit  Total Amount  DayOfWeek
# 354   55         1             500           500          5
# 970   27         4              50           200          1
# 8     63         2             300           600          2
# 581   35         3             300           900          1
# 56    63         1              30            30          5
# ..   ...       ...             ...           ...        ...
# 767   24         3              25            75          5
# 72    29         3              30            90          0
# 908   26         1             300           300          6
# 235   54         1              25            25          4
# 37    38         4              50           200          1
#
# [850 rows x 5 columns]

# %%
df_train.shape
# Out:
# (850, 5)

# %%
df_test.shape
# Out:
# (150, 5)

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['Age',	'Quantity',	'Price per Unit',	'DayOfWeek']]

y_train = df_train['Total Amount']
# df_test_predict = X_train.iloc[0:1]

# for linear regression
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)

# # #for logistic regression
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg_model = lg.fit(X_train, y_train)

# # # # #for polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=8)
X_poly = poly_reg.fit_transform(X_train)
# Y_poly = poly_reg.fit_transform(y_train)
pol_reg = LinearRegression()
model = pol_reg.fit(X_poly, y_train)
poly_reg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# PolynomialFeatures(degree=8)

# %%
# #to dump model
import pickle as pk
filename = 'model.pickle'
pk.dump(lr_model, open(filename, 'wb'))

# %%
data = df_test.iloc[50:51]
actual_totalamount = data['Total Amount']
data = data.drop(['Total Amount'],axis = 1)
data
# Out:
#      Age  Quantity  Price per Unit  DayOfWeek
# 713   18         1             500          6

# %%
#linear model
print("Predicted Total Amount	",lr_model.predict(data))
print("Actual Total Amount	",actual_totalamount)
# Out:
# Predicted Total Amount	 [989.58320884]
# Actual Total Amount	 713    500
# Name: Total Amount, dtype: int64

# %%
# #logistic
print("Predicted Total Amount",lg_model.predict(data))
print("Actual Total Amount",actual_totalamount)
# Out:
# Predicted Total Amount [1500]
# Actual Total Amount 713    500
# Name: Total Amount, dtype: int64

# %%
# # #polynomial regression model test
predicted_totalamount = pol_reg.predict(poly_reg.fit_transform(data))
print("Actual Total Amount",actual_totalamount)
print("predicted Total Amount",predicted_totalamount)
# Out:
# Actual Total Amount 713    500
# Name: Total Amount, dtype: int64
# predicted Total Amount [455.04554214]

# %%
#train acc
print("Linear regression = ",round(lr_model.score(X_train, y_train)*100))
print("Logistic regression = ",lg_model.score(X_train, y_train)*100),2
print("Polynomial regression = ",pol_reg.score(poly_reg.fit_transform(X_train), y_train)*100)
# Out:
# Linear regression =  85
# Logistic regression =  26.705882352941174
# Polynomial regression =  99.9709396520272

# %%
#test acc
test_data = df_test
y_test = test_data['Total Amount']
X_test = test_data.drop(['Total Amount'],axis = 1)

print("Linear regression = ",round(lr_model.score(X_test, y_test)*100))
print("Logistic regression = ",lg_model.score(X_test, y_test)*100)
print("Polynomial regression = ",pol_reg.score(poly_reg.fit_transform(X_test), y_test)*100)
# Out:
# Linear regression =  86
# Logistic regression =  23.333333333333332
# Polynomial regression =  99.96124853539335

# %%
# # Testing
data = df_test.iloc[32:33]
actual_totalamount = data.pop('Total Amount')

# # # print(data)
predicted_totalamount= pol_reg.predict(poly_reg.fit_transform(data))
print("Actual Total Amount",actual_totalamount)
print("predicted Total Amount",predicted_totalamount)

# # print(df_test.iloc[0:1])
# data
# Out:
# Actual Total Amount 744    100
# Name: Total Amount, dtype: int64
# predicted Total Amount [96.05586824]

# %%
data = {'Age':[55],
        'Quantity':[4],
        "Price per Unit":[450],
        "DayOfWeek":[5]}
df = pd.DataFrame(data)
predicted_totalamount =lr_model.predict(df)
# print("Actual Total Amount",actual_totalincome)
print("predicted Total Amount",np.round(predicted_totalamount,2))
df
# Out:
# predicted Total Amount [1368.55]
#    Age  Quantity  Price per Unit  DayOfWeek
# 0   55         4             450          5

# %%
plt.scatter(y_train,model.predict(poly_reg.fit_transform(X_train)),color = 'red')
plt.xlabel('Actual Total Amount')
plt.ylabel('Predicted Total Amount')
plt.show()

# %%
plt.scatter(y_train,lg_model.predict(X_train),color = 'red')
plt.xlabel('Actual Total Amount')
plt.ylabel('Predicted Total Amount')
plt.show()
